# %% [markdown]
# # Capstone Final Submission
#
# **DS2002 | 2026-04-26 | Homework**
#
# ---
#
# ## Submission Checklist
#
# Before submitting, verify every item. Check the box when done.
#
# - [ ] **Notebook runs top-to-bottom.** Restart kernel, Run All, no errors.
# - [ ] **GCS authentication** is demonstrated (download from bucket + upload to team folder).
# - [ ] **Data cleaning pipeline** is complete and documented (dedup, dates, costs, nulls, station IDs, vehicle IDs).
# - [ ] **Vehicle ID consolidation** is shown with before vs. after comparison.
# - [ ] **External API** data is pulled via `requests` and joined with charging data.
# - [ ] **All 5 analytical questions** are answered with code, charts, and written explanations.
# - [ ] **At least 6 visualizations** with proper titles, axis labels, and legends.
# - [ ] **Markdown cells** explain methodology and findings throughout.
# - [ ] **Reflection write-up** is complete (all 5 questions, all team members contributed).
# - [ ] **GCS team folder** contains your final cleaned data files.
# - [ ] **No leftover debugging cells**, print statements, or commented-out dead code.
# - [ ] **Code comments** explain non-obvious logic (not every line).

# %% [markdown]
# ## Grading Rubric (Reminder)
#
# | Component | Weight |
# |-----------|--------|
# | Cloud Pipeline | 15% |
# | Data Cleaning | 20% |
# | API Integration | 10% |
# | Analytical Questions (1-5) | 25% |
# | Visualizations | 15% |
# | Reflection Write-Up | 15% |

# %% [markdown]
# ## Reflection Questions
#
# Every team member should contribute. Write at least one solid paragraph per question.
#
# ### 1. Data Quality Impact
# > Describe a specific data quality issue you found. How did your cleaning decision change the outcome? What would have happened if you skipped it?
#
# *(your response)*
#
# ### 2. Cloud Pipeline Experience
# > What was the most confusing or frustrating part of working with GCS? What would you do differently? How does cloud storage compare to local files?
#
# *(your response)*
#
# ### 3. ETL Trade-offs
# > Pick one cleaning decision you made. What alternative approach could you have taken? How might it have changed your results?
#
# *(your response)*
#
# ### 4. Pipeline Trust
# > What is the most fragile part of your pipeline? If it had to run automatically every day, what would break first?
#
# *(your response)*
#
# ### 5. Team Collaboration
# > How did your team divide the work? What would you do differently with another week? What was the most valuable skill each member contributed?
#
# *(your response)*

# %% [markdown]
# ## How to Submit
#
# 1. Save your final notebook.
# 2. Verify one last time: Restart & Run All.
# 3. Submit via Kaggle (or your instructor's designated method).
# 4. One submission per team.
#
# **Deadline: Saturday, April 26, 11:59 PM.**
#
# Late submissions lose 10% per day. No exceptions unless you have already arranged an extension with your instructor.

# %% [markdown]
# ---
#
# That is it. You built a cloud data pipeline, cleaned messy data, pulled from an API, analyzed EV charging patterns, and presented your findings. That is a real data engineering workflow.
#
# Good work this semester.
