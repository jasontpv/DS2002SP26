# %% [markdown]
# # Capstone Progress Checkpoint
#
# **DS2002 | 2026-04-19 | Lab**
#
# ---
#
# ## Instructions
#
# This is a progress check, not a final submission. Your instructor or TA will review your notebook during lab. You do not need to present — just show your work.
#
# Fill in the status table below and make sure your notebook runs.

# %% [markdown]
# ## Team Information
#
# **Team Number:** `team-XX`
#
# **Team Members Present Today:**
# -
# -
# -

# %% [markdown]
# ## Checkpoint Rubric
#
# Mark each item as Done, In Progress, or Not Started.
#
# | # | Requirement | Status | Notes |
# |---|-------------|--------|-------|
# | 1 | GCS authentication works from Kaggle | | |
# | 2 | Raw data downloaded from bucket programmatically | | |
# | 3 | Cleaned data uploaded to team folder in GCS | | |
# | 4 | Data cleaning pipeline complete (dedup, dates, costs, nulls) | | |
# | 5 | Vehicle ID consolidation complete | | |
# | 6 | External API data pulled and parsed | | |
# | 7 | Question 1 answered with code + chart + explanation | | |
# | 8 | Question 2 answered with code + chart + explanation | | |
# | 9 | Question 3 answered with code + chart + explanation | | |
# | 10 | Question 4 answered with code + chart + explanation | | |
# | 11 | Question 5 answered with code + chart + explanation | | |
# | 12 | At least 6 visualizations total | | |
# | 13 | Notebook runs top-to-bottom (Restart & Run All) | | |

# %% [markdown]
# ## Minimum Bar for Checkpoint
#
# To pass the checkpoint, you must have:
# - Items 1-6 complete (cloud + cleaning + API)
# - At least 3 of the 5 questions answered
# - At least 4 visualizations
# - Notebook runs without errors
#
# If you are behind, talk to your instructor today about a recovery plan.

# %% [markdown]
# ## Blockers
#
# List anything that is blocking your progress. We will troubleshoot during lab.
#
# 1.
# 2.
# 3.

# %% [markdown]
# ## What is left to do?
#
# List your remaining tasks and who is responsible.
#
# | Task | Owner | Target Date |
# |------|-------|------------|
# | | | |
# | | | |
# | | | |
