# %% [markdown]
# # Analysis Clinic
#
# **DS2002 | 2026-04-15 | Studio (Hands-On Lab)**
#
# ---
#
# ## Overview
#
# Today is analysis day. Your data should be clean. Your goals:
#
# 1. Answer all 5 analytical questions from the project brief.
# 2. Build at least 6 visualizations.
# 3. Write markdown explanations for each question.
# 4. Join your external API data with the charging data.
#
# Your instructor and TAs are here to help with methodology and charting questions.

# %% [markdown]
# ## Setup
#
# Load your cleaned data. If you saved a SQLite database, load from there. Otherwise, load your cleaned CSVs.

# %%
import pandas as pd
import numpy as np
import sqlite3
import matplotlib.pyplot as plt
import seaborn as sns
import requests

# %matplotlib inline
sns.set_theme(style="whitegrid")

# Load your cleaned data
# conn = sqlite3.connect("ev_analytics.db")
# sessions = pd.read_sql("SELECT * FROM sessions", conn)
# stations = pd.read_sql("SELECT * FROM stations", conn)
# conn.close()
#
# Or load from CSV:
# sessions = pd.read_csv("cleaned_sessions.csv")

# %% [markdown]
# ## Question 1: Demand Surge Identification
#
# > Which time periods experienced the greatest charging demand surges compared to the baseline?
#
# Approach:
# - Group sessions by date.
# - Define "baseline" as the median daily session count during normal (non-surge) periods.
# - Identify surge periods and calculate percentage increase.
# - Plot daily sessions as a time series with surge periods highlighted.

# %%
# Your Q1 analysis here

# %% [markdown]
# **Findings:** *(write your interpretation)*

# %% [markdown]
# ## Question 2: The Vehicle Consolidation Problem
#
# > What is the true daily charging volume by vehicle type after consolidation?
#
# Approach:
# - Show a side-by-side comparison: fragmented vs. consolidated counts.
# - Pick the top 5 vehicles and show daily volume.
# - Explain what operational decisions would change.

# %%
# Your Q2 analysis here

# %% [markdown]
# **Findings:** *(write your interpretation)*

# %% [markdown]
# ## Question 3: Weather and Grid Correlation
#
# > How do temperature extremes correlate with demand and grid load?
#
# Approach:
# - Pull full-year weather data from your API.
# - Join with daily demand summary (by date).
# - Scatter plot: temperature vs. daily sessions or kWh.
# - Heatmap: monthly grid load by operator.
# - Discuss lag effects.

# %%
# Your Q3 analysis here
# Hint: the grid_capacity_levels table in the SQLite DB has temperature data too.

# %% [markdown]
# **Findings:** *(write your interpretation)*

# %% [markdown]
# Here is what the grid load heatmap looks like when built from the raw SQLite data. Your version should use your cleaned data.

# %%
# Pre-generated example: grid load heatmap by operator and month
# (This output is from the raw data — your version should use cleaned data)

# %% [markdown]
# ## Question 4: Station-Level Geographic Patterns
#
# > Do all stations experience the same usage patterns?
#
# Approach:
# - Join sessions with station locations.
# - Group by station, rank by total kWh.
# - Top 5 and bottom 5.
# - Look for geographic explanations (region, proximity to highways, university).

# %%
# Your Q4 analysis here

# %% [markdown]
# **Findings:** *(write your interpretation)*

# %% [markdown]
# ## Question 5: The Connector Type Investigation
#
# > Is the CHAdeMO decline real or a data artifact?
#
# Approach:
# - Group sessions by connector type and month.
# - Plot connector type share over time.
# - Cross-reference with vehicle types — which vehicles use CHAdeMO?
# - Check for missing connector values and whether they disproportionately affect CHAdeMO.
# - Make a recommendation: invest in more CHAdeMO ports or reallocate?

# %%
# Your Q5 analysis here

# %% [markdown]
# **Findings and recommendation:** *(write your interpretation)*

# %% [markdown]
# ---
#
# ## End of session checklist
#
# - [ ] All 5 questions have code, charts, and written explanations
# - [ ] At least 6 total visualizations
# - [ ] External API data joined with charging data
# - [ ] Notebook runs top-to-bottom without errors
#
# The progress checkpoint is Saturday (April 19). Everything above should be done by then.
