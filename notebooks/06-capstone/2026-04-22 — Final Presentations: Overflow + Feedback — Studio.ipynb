# %% [markdown]
# # Final Presentations: Overflow + Feedback
#
# **DS2002 | 2026-04-22 | Studio**
#
# ---

# %% [markdown]
# ## Today
#
# Teams that did not present on Sunday continue today. Same format: 8 minutes + 2 minutes Q&A.
#
# If your team already presented, you are expected to attend and provide peer feedback.

# %% [markdown]
# ## Peer Feedback
#
# For each team that presents today, write brief feedback. This is not graded — it is for the presenting team's benefit.
#
# ### Team ___
#
# **Strongest part of the presentation:**
#
#
# **One thing they could improve:**
#
#
# **Most interesting finding:**
#
# ---
#
# ### Team ___
#
# **Strongest part of the presentation:**
#
#
# **One thing they could improve:**
#
#
# **Most interesting finding:**
#
# ---
#
# ### Team ___
#
# **Strongest part of the presentation:**
#
#
# **One thing they could improve:**
#
#
# **Most interesting finding:**
#
# ---
#
# *(Copy this block for additional teams)*

# %% [markdown]
# ## After Presentations
#
# Once all teams have presented:
#
# 1. **Final submission is due Saturday, April 26.** See the submission notebook for the full checklist.
# 2. **Reflections are part of the submission.** Every team member writes their own responses.
# 3. **Clean up your notebook.** Remove debugging cells, add section headers, restart and run all.
# 4. **Verify your GCS team folder** has your final cleaned data files.
#
# This is the last in-class session for the capstone. Any remaining questions, ask today or on Piazza.
